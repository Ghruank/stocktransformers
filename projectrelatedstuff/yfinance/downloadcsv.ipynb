# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
stock = "HINDUNILVR.NS"

# %%
data = yf.download(stock, period="max")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data = data[['Open', 'High', 'Low', 'Volume', 'Adj Close', 'Close']]

# %%
data.to_csv(f"hul.csv")

# %%
plt.figure(figsize=(10, 5))
plt.plot(yf.Ticker(stock).history(period="max")["Close"])
plt.title(f"All-Time Price History")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.grid(True)
plt.show()
