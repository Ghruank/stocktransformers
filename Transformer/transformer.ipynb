# %%
import math
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add, GlobalAveragePooling1D

import yfinance as yf

# %%
def calculate_bollinger_bands(data, window=10, num_of_std=2):
    """Calculate Bollinger Bands"""
    rolling_mean = data.rolling(window=window).mean()
    rolling_std = data.rolling(window=window).std()
    upper_band = rolling_mean + (rolling_std * num_of_std)
    lower_band = rolling_mean - (rolling_std * num_of_std)
    return upper_band, lower_band

def calculate_rsi(data, window=10):
    """Calculate Relative Strength Index"""
    delta = data.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_roc(data, periods=10):
    """Calculate Rate of Change."""
    roc = ((data - data.shift(periods)) / data.shift(periods)) * 100
    return roc

# %%
tickers = ['TCS.NS']

# %%
ticker_data_frames = []
stats = {}
for ticker in tickers:

    # Download historical data for the ticker
    data = yf.download(ticker, period="1mo", interval="5m")

    # Calculate the daily percentage change
    close = data['Close']
    upper, lower = calculate_bollinger_bands(close, window=14, num_of_std=2)
    width = upper - lower
    rsi = calculate_rsi(close, window=14)
    roc = calculate_roc(close, periods=14)
    volume = data['Volume']
    diff = data['Close'].diff(1)
    percent_change_close = data['Close'].pct_change() * 100

    # Create a DataFrame for the current ticker and append it to the list
    ticker_df = pd.DataFrame({
        ticker+'_close': close,
        ticker+'_width': width,
        ticker+'_rsi': rsi,
        ticker+'_roc': roc,
        ticker+'_volume': volume,
        ticker+'_diff': diff,
        ticker+'_percent_change_close': percent_change_close,
    })

    MEAN = ticker_df.mean()
    STD = ticker_df.std()

    # Keep track of mean and std
    for column in MEAN.index:
      stats[f"{column}_mean"] = MEAN[column]
      stats[f"{column}_std"] = STD[column]

    # Normalize the training features
    ticker_df = (ticker_df - MEAN) / STD

    ticker_data_frames.append(ticker_df)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Convert the dictionary containing feature statistics to a DataFrame for easier access
stats = pd.DataFrame([stats], index=[0])

# Display the DataFrame to verify its structure
stats.head()
# Out:
#    TCS.NS_close_mean  TCS.NS_close_std  TCS.NS_width_mean  TCS.NS_width_std  \
# 0        4372.356539        109.431736          28.721017         24.066649
#
#    TCS.NS_rsi_mean  TCS.NS_rsi_std  TCS.NS_roc_mean  TCS.NS_roc_std  \
# 0        47.699056       16.453029        -0.046024        0.492515
#
#    TCS.NS_volume_mean  TCS.NS_volume_std  TCS.NS_diff_mean  TCS.NS_diff_std  \
# 0        30195.917513       34735.623307         -0.144825         6.052543
#
#    TCS.NS_percent_change_close_mean  TCS.NS_percent_change_close_std
# 0                         -0.003219                         0.138756

# %%
df = pd.concat(ticker_data_frames, axis=1)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#                            TCS.NS_close  TCS.NS_width  TCS.NS_rsi  TCS.NS_roc  \
# Datetime
# 2024-09-05 10:05:00+05:30      0.812774     -0.013390   -1.202227   -0.891620
# 2024-09-05 10:10:00+05:30      0.821002     -0.020834   -0.990359   -0.692938
# 2024-09-05 10:15:00+05:30      0.896846     -0.124228   -0.399719   -0.343884
# 2024-09-05 10:20:00+05:30      0.966297     -0.274737   -0.168748   -0.173705
# 2024-09-05 10:25:00+05:30      0.926090     -0.284449    0.093989    0.057155
#
#                            TCS.NS_volume  TCS.NS_diff  \
# Datetime
# 2024-09-05 10:05:00+05:30      -0.591264    -0.298283
# 2024-09-05 10:10:00+05:30      -0.618498     0.172690
# 2024-09-05 10:15:00+05:30      -0.579057     1.395220
# 2024-09-05 10:20:00+05:30      -0.107150     1.279615
# 2024-09-05 10:25:00+05:30      -0.433933    -0.703023
#
#                            TCS.NS_percent_change_close
# Datetime
# 2024-09-05 10:05:00+05:30                    -0.291701
# 2024-09-05 10:10:00+05:30                     0.168653
# 2024-09-05 10:15:00+05:30                     1.363703
# 2024-09-05 10:20:00+05:30                     1.248414
# 2024-09-05 10:25:00+05:30                    -0.684904

# %%
# Shift the dataframe up by one to align current features with the next step's outcomes
labels = df.shift(-1)

# Remove the last row from both the features and labels to maintain consistent data pairs
df = df.iloc[:-1]
labels = labels.iloc[:-1]

# %%
SEQUENCE_LEN = 24  # 2 hours of data at 5-minute intervals

def create_sequences(data, labels, mean, std, sequence_length=SEQUENCE_LEN):
    sequences = []
    lab = []
    data_size = len(data)

    # Loop to create each sequence and its corresponding label
    for i in range(data_size - (sequence_length + 13)): # Ensure we have data for the label
        if i == 0:
          continue
        sequences.append(data[i:i + sequence_length])  # The sequence of data
        lab.append([labels[i-1], labels[i + 12], mean[0], std[0]]) # The label and scaling factors

    return np.array(sequences), np.array(lab)

# %%
sequences_dict = {}
sequence_labels = {}
for ticker in tickers:

    # Extract close and volume data for the ticker
    close = df[ticker+'_close'].values
    width = df[ticker+'_width'].values
    rsi = df[ticker+'_rsi'].values
    roc = df[ticker+'_roc'].values
    volume = df[ticker+'_volume'].values
    diff = df[ticker+'_diff'].values
    pct_change = df[ticker+'_percent_change_close'].values

    # Combine close and volume data
    ticker_data = np.column_stack((close,
                                   width,
                                   rsi,
                                   roc,
                                   volume,
                                   diff,
                                   pct_change))

    # Generate sequences
    attribute = ticker+"_close"
    ticker_sequences, lab = create_sequences(ticker_data,
                                             labels[attribute].values[SEQUENCE_LEN-1:],
                                             stats[attribute+"_mean"].values,
                                             stats[attribute+"_std"].values)

    sequences_dict[ticker] = ticker_sequences
    sequence_labels[ticker] = lab

# %%
pd.DataFrame(sequence_labels[tickers[0]][0])
# Out:
#              0
# 0     0.801351
# 1     0.779421
# 2  4372.356539
# 3   109.431736

# %%
# Combine data and labels from all tickers
all_sequences = []
all_labels = []

for ticker in tickers:
    all_sequences.extend(sequences_dict[ticker])
    all_labels.extend(sequence_labels[ticker])

# Convert to numpy arrays
all_sequences = np.array(all_sequences)
all_labels = np.array(all_labels)

# %%
np.random.seed(42)
shuffled_indices = np.random.permutation(len(all_sequences))
all_sequences = all_sequences[shuffled_indices]
all_labels = all_labels[shuffled_indices]

train_size = int(len(all_sequences) * 0.9)

# Split sequences
train_sequences = all_sequences[:train_size]
train_labels    = all_labels[:train_size]

other_sequences = all_sequences[train_size:]
other_labels    = all_labels[train_size:]

shuffled_indices = np.random.permutation(len(other_sequences))
other_sequences = other_sequences[shuffled_indices]
other_labels = other_labels[shuffled_indices]

val_size = int(len(other_sequences) * 0.5)

validation_sequences = other_sequences[:val_size]
validation_labels = other_labels[:val_size]

test_sequences = other_sequences[val_size:]
test_labels = other_labels[val_size:]

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    # Feed Forward Part
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation="relu")(y)
    y = Dropout(dropout)(y)
    y = Dense(inputs.shape[-1])(y)
    return Add()([y, x])

# %%
def build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout=0):
    inputs = Input(shape=input_shape)
    x = inputs
    for _ in range(num_layers):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
    x = GlobalAveragePooling1D()(x)
    x = LayerNormalization(epsilon=1e-6)(x)
    outputs = Dense(1, activation="linear")(x)
    return Model(inputs=inputs, outputs=outputs)

# %%
input_shape = train_sequences.shape[1:]
head_size = 256
num_heads = 16
ff_dim = 1024
num_layers = 12
dropout = 0.20

model = build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 24, 7)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 24, 7)          │             14 │ input_layer[0][0]      │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 24, 7)          │        126,983 │ layer_normalization[0… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 24, 7)          │              0 │ multi_head_attention[… │
# │                           │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 24, 7)          │             14 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 24, 1024)       │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 24, 7)          │              0 │ dense_1[0][0],         │
# │                           │                        │                │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_2     │ (None, 24, 7)          │             14 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_1    │ (None, 24, 7)          │        126,983 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_3     │ (None, 24, 7)          │             14 │ add_2[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 24, 7)          │              0 │ dense_3[0][0],         │
# │                           │                        │                │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_4     │ (None, 24, 7)          │             14 │ add_3[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_2    │ (None, 24, 7)          │        126,983 │ layer_normalization_4… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_5     │ (None, 24, 7)          │             14 │ add_4[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 24, 7)          │              0 │ dense_5[0][0],         │
# │                           │                        │                │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_6     │ (None, 24, 7)          │             14 │ add_5[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_3    │ (None, 24, 7)          │        126,983 │ layer_normalization_6… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_7     │ (None, 24, 7)          │             14 │ add_6[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 24, 7)          │              0 │ dense_7[0][0],         │
# │                           │                        │                │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_8     │ (None, 24, 7)          │             14 │ add_7[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_4    │ (None, 24, 7)          │        126,983 │ layer_normalization_8… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 24, 7)          │             14 │ add_8[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 24, 1024)       │          8,192 │ layer_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 24, 1024)       │              0 │ dense_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 24, 7)          │          7,175 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 24, 7)          │              0 │ dense_9[0][0],         │
# │                           │                        │                │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 24, 7)          │             14 │ add_9[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_5    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 24, 7)          │             14 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 24, 7)          │              0 │ dense_11[0][0],        │
# │                           │                        │                │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 24, 7)          │             14 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 24, 7)          │             14 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 24, 7)          │              0 │ dense_13[0][0],        │
# │                           │                        │                │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 24, 7)          │             14 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_13[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 24, 7)          │             14 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 24, 7)          │              0 │ dense_15[0][0],        │
# │                           │                        │                │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_16    │ (None, 24, 7)          │             14 │ add_15[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_8    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_15[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_17    │ (None, 24, 7)          │             14 │ add_16[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 24, 7)          │              0 │ dense_17[0][0],        │
# │                           │                        │                │ add_16[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_18    │ (None, 24, 7)          │             14 │ add_17[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_9    │ (None, 24, 7)          │        126,983 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_17[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_19    │ (None, 24, 7)          │             14 │ add_18[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_19 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_19[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 24, 7)          │              0 │ dense_19[0][0],        │
# │                           │                        │                │ add_18[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_20    │ (None, 24, 7)          │             14 │ add_19[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_10   │ (None, 24, 7)          │        126,983 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_19[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_21    │ (None, 24, 7)          │             14 │ add_20[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_21 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_21[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_21 (Add)              │ (None, 24, 7)          │              0 │ dense_21[0][0],        │
# │                           │                        │                │ add_20[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_22    │ (None, 24, 7)          │             14 │ add_21[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_11   │ (None, 24, 7)          │        126,983 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_22 (Add)              │ (None, 24, 7)          │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_21[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_23    │ (None, 24, 7)          │             14 │ add_22[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 24, 1024)       │          8,192 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_23 (Dropout)      │ (None, 24, 1024)       │              0 │ dense_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 24, 7)          │          7,175 │ dropout_23[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_23 (Add)              │ (None, 24, 7)          │              0 │ dense_23[0][0],        │
# │                           │                        │                │ add_22[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 7)              │              0 │ add_23[0][0]           │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_24    │ (None, 7)              │             14 │ global_average_poolin… │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 1)              │              8 │ layer_normalization_2… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,708,558 (6.52 MB)
#  Trainable params: 1,708,558 (6.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def custom_mae_loss(y_true, y_pred):
    y_true_next = tf.cast(y_true[:, 1], tf.float64)  # Extract the true next values, scaled
    y_pred_next = tf.cast(y_pred[:, 0], tf.float64)  # Extract the predicted next values, scaled
    abs_error = tf.abs(y_true_next - y_pred_next)  # Calculate the absolute error
    return tf.reduce_mean(abs_error)  # Return the mean of these errors

def dir_acc(y_true, y_pred):
    mean, std = tf.cast(y_true[:, 2], tf.float64), tf.cast(y_true[:, 3], tf.float64)  # Retrieve scaling factors
    y_true_prev = (tf.cast(y_true[:, 0], tf.float64) * std) + mean  # Un-scale previous true price
    y_true_next = (tf.cast(y_true[:, 1], tf.float64) * std) + mean  # Un-scale next true price
    y_pred_next = (tf.cast(y_pred[:, 0], tf.float64) * std) + mean  # Un-scale predicted next price

    true_change = y_true_next - y_true_prev  # Calculate true change
    pred_change = y_pred_next - y_true_prev  # Calculate predicted change

    correct_direction = tf.equal(tf.sign(true_change), tf.sign(pred_change))  # Check if the signs match
    return tf.reduce_mean(tf.cast(correct_direction, tf.float64))  # Return the mean of correct directions

# %%
# Define a callback to save the best model
checkpoint_callback_train = ModelCheckpoint(
    "transformer_train_model.keras",  # Filepath to save the best model
    monitor="dir_acc",  #"loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

# Define a callback to save the best model
checkpoint_callback_val = ModelCheckpoint(
    "transformer_val_model.keras",  # Filepath to save the best model
    monitor="val_dir_acc", #"val_loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

def get_lr_callback(batch_size=16, mode='cos', epochs=500, plot=False):
    lr_start, lr_max, lr_min = 0.0001, 0.005, 0.00001  # Adjust learning rate boundaries
    lr_ramp_ep = int(0.30 * epochs)  # 30% of epochs for warm-up
    lr_sus_ep = max(0, int(0.10 * epochs) - lr_ramp_ep)  # Optional sustain phase, adjust as needed

    def lrfn(epoch):
        if epoch < lr_ramp_ep:  # Warm-up phase
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        elif epoch < lr_ramp_ep + lr_sus_ep:  # Sustain phase at max learning rate
            lr = lr_max
        elif mode == 'cos':
            decay_total_epochs, decay_epoch_index = epochs - lr_ramp_ep - lr_sus_ep, epoch - lr_ramp_ep - lr_sus_ep
            phase = math.pi * decay_epoch_index / decay_total_epochs
            lr = (lr_max - lr_min) * 0.5 * (1 + math.cos(phase)) + lr_min
        else:
            lr = lr_min  # Default to minimum learning rate if mode is not recognized

        return lr

    if plot:  # Plot learning rate curve if plot is True
        plt.figure(figsize=(10, 5))
        plt.plot(np.arange(epochs), [lrfn(epoch) for epoch in np.arange(epochs)], marker='o')
        plt.xlabel('Epoch')
        plt.ylabel('Learning Rate')
        plt.title('Learning Rate Scheduler')
        plt.show()

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %%
# prompt: compile the model

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=custom_mae_loss,
    metrics=[dir_acc]
)

# %%
BATCH_SIZE = 64  # Number of training examples used to calculate each iteration's gradient
EPOCHS = 100  # Total number of times the entire dataset is passed through the network

model.fit(
    train_sequences,  # Training features
    train_labels,  # Training labels
    validation_data=(validation_sequences, validation_labels),  # Validation data
    epochs=EPOCHS,  # Number of epochs to train for
    batch_size=BATCH_SIZE,  # Size of each batch
    shuffle=True,  # Shuffle training data before each epoch
    callbacks=[checkpoint_callback_train, checkpoint_callback_val, get_lr_callback(batch_size=BATCH_SIZE, epochs=EPOCHS)]  # Callbacks for saving models and adjusting learning rate
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - dir_acc: 0.5443 - loss: 0.3289
# Epoch 1: dir_acc improved from -inf to 0.54803, saving model to transformer_train_model.keras
#
# Epoch 1: val_dir_acc improved from -inf to 0.52679, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 111s 418ms/step - dir_acc: 0.5443 - loss: 0.3283 - val_dir_acc: 0.5268 - val_loss: 0.2366 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00026333333333333336.
# Epoch 2/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dir_acc: 0.5488 - loss: 0.2522
# Epoch 2: dir_acc improved from 0.54803 to 0.55193, saving model to transformer_train_model.keras
#
# Epoch 2: val_dir_acc improved from 0.52679 to 0.57232, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - dir_acc: 0.5488 - loss: 0.2521 - val_dir_acc: 0.5723 - val_loss: 0.2229 - learning_rate: 2.6333e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00042666666666666667.
# Epoch 3/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dir_acc: 0.5657 - loss: 0.2406
# Epoch 3: dir_acc improved from 0.55193 to 0.55796, saving model to transformer_train_model.keras
#
# Epoch 3: val_dir_acc improved from 0.57232 to 0.62009, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - dir_acc: 0.5656 - loss: 0.2406 - val_dir_acc: 0.6201 - val_loss: 0.2281 - learning_rate: 4.2667e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00059.
# Epoch 4/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.5460 - loss: 0.2433
# Epoch 4: dir_acc did not improve from 0.55796
#
# Epoch 4: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - dir_acc: 0.5460 - loss: 0.2433 - val_dir_acc: 0.5045 - val_loss: 0.2469 - learning_rate: 5.9000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0007533333333333334.
# Epoch 5/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.5549 - loss: 0.2343
# Epoch 5: dir_acc improved from 0.55796 to 0.55931, saving model to transformer_train_model.keras
#
# Epoch 5: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - dir_acc: 0.5549 - loss: 0.2342 - val_dir_acc: 0.5589 - val_loss: 0.1991 - learning_rate: 7.5333e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0009166666666666668.
# Epoch 6/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.5719 - loss: 0.2126
# Epoch 6: dir_acc improved from 0.55931 to 0.56524, saving model to transformer_train_model.keras
#
# Epoch 6: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.5718 - loss: 0.2127 - val_dir_acc: 0.5192 - val_loss: 0.2040 - learning_rate: 9.1667e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00108.
# Epoch 7/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.5725 - loss: 0.2170
# Epoch 7: dir_acc did not improve from 0.56524
#
# Epoch 7: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - dir_acc: 0.5724 - loss: 0.2170 - val_dir_acc: 0.4625 - val_loss: 0.2621 - learning_rate: 0.0011
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0012433333333333335.
# Epoch 8/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.5773 - loss: 0.2165
# Epoch 8: dir_acc improved from 0.56524 to 0.57096, saving model to transformer_train_model.keras
#
# Epoch 8: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - dir_acc: 0.5772 - loss: 0.2165 - val_dir_acc: 0.5759 - val_loss: 0.2077 - learning_rate: 0.0012
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0014066666666666667.
# Epoch 9/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.5923 - loss: 0.2110
# Epoch 9: dir_acc improved from 0.57096 to 0.59328, saving model to transformer_train_model.keras
#
# Epoch 9: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - dir_acc: 0.5923 - loss: 0.2109 - val_dir_acc: 0.5076 - val_loss: 0.1872 - learning_rate: 0.0014
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00157.
# Epoch 10/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.5944 - loss: 0.1925
# Epoch 10: dir_acc improved from 0.59328 to 0.59550, saving model to transformer_train_model.keras
#
# Epoch 10: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - dir_acc: 0.5944 - loss: 0.1925 - val_dir_acc: 0.5763 - val_loss: 0.1892 - learning_rate: 0.0016
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0017333333333333335.
# Epoch 11/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.5775 - loss: 0.2009
# Epoch 11: dir_acc did not improve from 0.59550
#
# Epoch 11: val_dir_acc did not improve from 0.62009
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - dir_acc: 0.5776 - loss: 0.2008 - val_dir_acc: 0.5451 - val_loss: 0.2044 - learning_rate: 0.0017
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0018966666666666667.
# Epoch 12/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6094 - loss: 0.1917
# Epoch 12: dir_acc improved from 0.59550 to 0.59998, saving model to transformer_train_model.keras
#
# Epoch 12: val_dir_acc improved from 0.62009 to 0.62589, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - dir_acc: 0.6094 - loss: 0.1917 - val_dir_acc: 0.6259 - val_loss: 0.1875 - learning_rate: 0.0019
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0020599999999999998.
# Epoch 13/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6085 - loss: 0.1799
# Epoch 13: dir_acc improved from 0.59998 to 0.61456, saving model to transformer_train_model.keras
#
# Epoch 13: val_dir_acc did not improve from 0.62589
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - dir_acc: 0.6086 - loss: 0.1799 - val_dir_acc: 0.6152 - val_loss: 0.1755 - learning_rate: 0.0021
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0022233333333333332.
# Epoch 14/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6190 - loss: 0.1731
# Epoch 14: dir_acc did not improve from 0.61456
#
# Epoch 14: val_dir_acc did not improve from 0.62589
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - dir_acc: 0.6189 - loss: 0.1732 - val_dir_acc: 0.6018 - val_loss: 0.1688 - learning_rate: 0.0022
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0023866666666666667.
# Epoch 15/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6173 - loss: 0.1747
# Epoch 15: dir_acc improved from 0.61456 to 0.62227, saving model to transformer_train_model.keras
#
# Epoch 15: val_dir_acc improved from 0.62589 to 0.63036, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - dir_acc: 0.6173 - loss: 0.1747 - val_dir_acc: 0.6304 - val_loss: 0.1762 - learning_rate: 0.0024
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0025499999999999997.
# Epoch 16/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6251 - loss: 0.1703
# Epoch 16: dir_acc improved from 0.62227 to 0.62487, saving model to transformer_train_model.keras
#
# Epoch 16: val_dir_acc did not improve from 0.63036
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - dir_acc: 0.6251 - loss: 0.1703 - val_dir_acc: 0.6116 - val_loss: 0.1547 - learning_rate: 0.0026
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0027133333333333332.
# Epoch 17/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6296 - loss: 0.1690
# Epoch 17: dir_acc improved from 0.62487 to 0.63476, saving model to transformer_train_model.keras
#
# Epoch 17: val_dir_acc improved from 0.63036 to 0.68259, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - dir_acc: 0.6296 - loss: 0.1690 - val_dir_acc: 0.6826 - val_loss: 0.1497 - learning_rate: 0.0027
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0028766666666666667.
# Epoch 18/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6145 - loss: 0.1754
# Epoch 18: dir_acc did not improve from 0.63476
#
# Epoch 18: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step - dir_acc: 0.6147 - loss: 0.1753 - val_dir_acc: 0.5973 - val_loss: 0.1920 - learning_rate: 0.0029
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0030399999999999997.
# Epoch 19/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.6294 - loss: 0.1740
# Epoch 19: dir_acc did not improve from 0.63476
#
# Epoch 19: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - dir_acc: 0.6294 - loss: 0.1739 - val_dir_acc: 0.5638 - val_loss: 0.2466 - learning_rate: 0.0030
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.003203333333333333.
# Epoch 20/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6270 - loss: 0.1819
# Epoch 20: dir_acc did not improve from 0.63476
#
# Epoch 20: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - dir_acc: 0.6270 - loss: 0.1818 - val_dir_acc: 0.6219 - val_loss: 0.1564 - learning_rate: 0.0032
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0033666666666666667.
# Epoch 21/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6351 - loss: 0.1653
# Epoch 21: dir_acc improved from 0.63476 to 0.63662, saving model to transformer_train_model.keras
#
# Epoch 21: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - dir_acc: 0.6351 - loss: 0.1653 - val_dir_acc: 0.5875 - val_loss: 0.1485 - learning_rate: 0.0034
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0035299999999999997.
# Epoch 22/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6496 - loss: 0.1694
# Epoch 22: dir_acc improved from 0.63662 to 0.64453, saving model to transformer_train_model.keras
#
# Epoch 22: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.6495 - loss: 0.1694 - val_dir_acc: 0.5906 - val_loss: 0.1617 - learning_rate: 0.0035
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.003693333333333333.
# Epoch 23/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6350 - loss: 0.1681
# Epoch 23: dir_acc did not improve from 0.64453
#
# Epoch 23: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - dir_acc: 0.6350 - loss: 0.1681 - val_dir_acc: 0.6696 - val_loss: 0.1446 - learning_rate: 0.0037
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0038566666666666667.
# Epoch 24/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6433 - loss: 0.1661
# Epoch 24: dir_acc did not improve from 0.64453
#
# Epoch 24: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - dir_acc: 0.6432 - loss: 0.1662 - val_dir_acc: 0.6348 - val_loss: 0.1962 - learning_rate: 0.0039
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00402.
# Epoch 25/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6462 - loss: 0.1667
# Epoch 25: dir_acc improved from 0.64453 to 0.64850, saving model to transformer_train_model.keras
#
# Epoch 25: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - dir_acc: 0.6462 - loss: 0.1667 - val_dir_acc: 0.6362 - val_loss: 0.1811 - learning_rate: 0.0040
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.004183333333333334.
# Epoch 26/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6480 - loss: 0.1716
# Epoch 26: dir_acc improved from 0.64850 to 0.65329, saving model to transformer_train_model.keras
#
# Epoch 26: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - dir_acc: 0.6480 - loss: 0.1716 - val_dir_acc: 0.6384 - val_loss: 0.1546 - learning_rate: 0.0042
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.004346666666666667.
# Epoch 27/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6494 - loss: 0.1566
# Epoch 27: dir_acc did not improve from 0.65329
#
# Epoch 27: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - dir_acc: 0.6494 - loss: 0.1567 - val_dir_acc: 0.6438 - val_loss: 0.1741 - learning_rate: 0.0043
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00451.
# Epoch 28/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6503 - loss: 0.1683
# Epoch 28: dir_acc did not improve from 0.65329
#
# Epoch 28: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - dir_acc: 0.6503 - loss: 0.1682 - val_dir_acc: 0.6496 - val_loss: 0.1539 - learning_rate: 0.0045
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004673333333333334.
# Epoch 29/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6635 - loss: 0.1548
# Epoch 29: dir_acc improved from 0.65329 to 0.66130, saving model to transformer_train_model.keras
#
# Epoch 29: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - dir_acc: 0.6635 - loss: 0.1548 - val_dir_acc: 0.5951 - val_loss: 0.1652 - learning_rate: 0.0047
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.004836666666666667.
# Epoch 30/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6745 - loss: 0.1555
# Epoch 30: dir_acc improved from 0.66130 to 0.66741, saving model to transformer_train_model.keras
#
# Epoch 30: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - dir_acc: 0.6744 - loss: 0.1556 - val_dir_acc: 0.6098 - val_loss: 0.1622 - learning_rate: 0.0048
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.005.
# Epoch 31/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6480 - loss: 0.1642
# Epoch 31: dir_acc did not improve from 0.66741
#
# Epoch 31: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step - dir_acc: 0.6481 - loss: 0.1641 - val_dir_acc: 0.6661 - val_loss: 0.1452 - learning_rate: 0.0050
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00499748770102058.
# Epoch 32/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dir_acc: 0.6584 - loss: 0.1515
# Epoch 32: dir_acc did not improve from 0.66741
#
# Epoch 32: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step - dir_acc: 0.6584 - loss: 0.1515 - val_dir_acc: 0.6205 - val_loss: 0.1621 - learning_rate: 0.0050
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0049899558635181215.
# Epoch 33/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6679 - loss: 0.1480
# Epoch 33: dir_acc improved from 0.66741 to 0.67072, saving model to transformer_train_model.keras
#
# Epoch 33: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - dir_acc: 0.6679 - loss: 0.1480 - val_dir_acc: 0.6254 - val_loss: 0.1544 - learning_rate: 0.0050
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.004977419655610997.
# Epoch 34/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6407 - loss: 0.1605
# Epoch 34: dir_acc did not improve from 0.67072
#
# Epoch 34: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - dir_acc: 0.6408 - loss: 0.1605 - val_dir_acc: 0.6210 - val_loss: 0.1506 - learning_rate: 0.0050
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.004959904323553581.
# Epoch 35/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6426 - loss: 0.1641
# Epoch 35: dir_acc did not improve from 0.67072
#
# Epoch 35: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - dir_acc: 0.6427 - loss: 0.1641 - val_dir_acc: 0.5920 - val_loss: 0.1642 - learning_rate: 0.0050
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0049374451408936496.
# Epoch 36/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6850 - loss: 0.1544
# Epoch 36: dir_acc improved from 0.67072 to 0.68240, saving model to transformer_train_model.keras
#
# Epoch 36: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - dir_acc: 0.6850 - loss: 0.1544 - val_dir_acc: 0.6018 - val_loss: 0.1624 - learning_rate: 0.0049
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.004910087337436154.
# Epoch 37/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.6626 - loss: 0.1521
# Epoch 37: dir_acc did not improve from 0.68240
#
# Epoch 37: val_dir_acc did not improve from 0.68259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - dir_acc: 0.6627 - loss: 0.1520 - val_dir_acc: 0.5964 - val_loss: 0.1559 - learning_rate: 0.0049
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.004877886008156408.
# Epoch 38/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6722 - loss: 0.1523
# Epoch 38: dir_acc did not improve from 0.68240
#
# Epoch 38: val_dir_acc improved from 0.68259 to 0.69063, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.6722 - loss: 0.1523 - val_dir_acc: 0.6906 - val_loss: 0.1305 - learning_rate: 0.0049
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.004840906002246144.
# Epoch 39/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6922 - loss: 0.1399
# Epoch 39: dir_acc improved from 0.68240 to 0.68259, saving model to transformer_train_model.keras
#
# Epoch 39: val_dir_acc improved from 0.69063 to 0.69241, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - dir_acc: 0.6921 - loss: 0.1399 - val_dir_acc: 0.6924 - val_loss: 0.1368 - learning_rate: 0.0048
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00479922179251587.
# Epoch 40/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6973 - loss: 0.1407
# Epoch 40: dir_acc improved from 0.68259 to 0.68522, saving model to transformer_train_model.keras
#
# Epoch 40: val_dir_acc did not improve from 0.69241
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - dir_acc: 0.6972 - loss: 0.1407 - val_dir_acc: 0.6598 - val_loss: 0.1313 - learning_rate: 0.0048
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0047529173254165355.
# Epoch 41/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7076 - loss: 0.1349
# Epoch 41: dir_acc improved from 0.68522 to 0.69340, saving model to transformer_train_model.keras
#
# Epoch 41: val_dir_acc did not improve from 0.69241
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - dir_acc: 0.7075 - loss: 0.1349 - val_dir_acc: 0.6107 - val_loss: 0.1493 - learning_rate: 0.0048
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.004702085851982562.
# Epoch 42/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.6884 - loss: 0.1443
# Epoch 42: dir_acc did not improve from 0.69340
#
# Epoch 42: val_dir_acc improved from 0.69241 to 0.69911, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - dir_acc: 0.6885 - loss: 0.1443 - val_dir_acc: 0.6991 - val_loss: 0.1430 - learning_rate: 0.0047
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.004646829740036656.
# Epoch 43/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6878 - loss: 0.1390
# Epoch 43: dir_acc did not improve from 0.69340
#
# Epoch 43: val_dir_acc did not improve from 0.69911
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - dir_acc: 0.6878 - loss: 0.1390 - val_dir_acc: 0.6772 - val_loss: 0.1286 - learning_rate: 0.0046
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00458726026803465.
# Epoch 44/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7160 - loss: 0.1291
# Epoch 44: dir_acc improved from 0.69340 to 0.70453, saving model to transformer_train_model.keras
#
# Epoch 44: val_dir_acc did not improve from 0.69911
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.7159 - loss: 0.1291 - val_dir_acc: 0.6884 - val_loss: 0.1199 - learning_rate: 0.0046
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.004523497400965494.
# Epoch 45/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6962 - loss: 0.1350
# Epoch 45: dir_acc did not improve from 0.70453
#
# Epoch 45: val_dir_acc did not improve from 0.69911
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - dir_acc: 0.6962 - loss: 0.1350 - val_dir_acc: 0.6696 - val_loss: 0.1286 - learning_rate: 0.0045
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.004455669548757734.
# Epoch 46/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6946 - loss: 0.1324
# Epoch 46: dir_acc did not improve from 0.70453
#
# Epoch 46: val_dir_acc did not improve from 0.69911
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - dir_acc: 0.6945 - loss: 0.1324 - val_dir_acc: 0.6638 - val_loss: 0.1396 - learning_rate: 0.0045
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00438391330767901.
# Epoch 47/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.7164 - loss: 0.1296
# Epoch 47: dir_acc improved from 0.70453 to 0.71085, saving model to transformer_train_model.keras
#
# Epoch 47: val_dir_acc did not improve from 0.69911
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - dir_acc: 0.7163 - loss: 0.1296 - val_dir_acc: 0.6576 - val_loss: 0.1260 - learning_rate: 0.0044
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.004308373185249342.
# Epoch 48/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7056 - loss: 0.1265
# Epoch 48: dir_acc did not improve from 0.71085
#
# Epoch 48: val_dir_acc did not improve from 0.69911
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - dir_acc: 0.7055 - loss: 0.1265 - val_dir_acc: 0.6750 - val_loss: 0.1304 - learning_rate: 0.0043
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.004229201309222228.
# Epoch 49/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.6943 - loss: 0.1374
# Epoch 49: dir_acc did not improve from 0.71085
#
# Epoch 49: val_dir_acc improved from 0.69911 to 0.70089, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - dir_acc: 0.6943 - loss: 0.1373 - val_dir_acc: 0.7009 - val_loss: 0.1244 - learning_rate: 0.0042
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0041465571212195825.
# Epoch 50/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7172 - loss: 0.1279
# Epoch 50: dir_acc did not improve from 0.71085
#
# Epoch 50: val_dir_acc improved from 0.70089 to 0.72054, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - dir_acc: 0.7171 - loss: 0.1279 - val_dir_acc: 0.7205 - val_loss: 0.1246 - learning_rate: 0.0041
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0040606070556375405.
# Epoch 51/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dir_acc: 0.7214 - loss: 0.1182
# Epoch 51: dir_acc improved from 0.71085 to 0.71657, saving model to transformer_train_model.keras
#
# Epoch 51: val_dir_acc did not improve from 0.72054
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - dir_acc: 0.7214 - loss: 0.1182 - val_dir_acc: 0.7004 - val_loss: 0.1378 - learning_rate: 0.0041
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00397152420446972.
# Epoch 52/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7158 - loss: 0.1277
# Epoch 52: dir_acc improved from 0.71657 to 0.71767, saving model to transformer_train_model.keras
#
# Epoch 52: val_dir_acc improved from 0.72054 to 0.73259, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - dir_acc: 0.7158 - loss: 0.1277 - val_dir_acc: 0.7326 - val_loss: 0.1208 - learning_rate: 0.0040
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0038794879687229964.
# Epoch 53/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7263 - loss: 0.1176
# Epoch 53: dir_acc improved from 0.71767 to 0.71801, saving model to transformer_train_model.keras
#
# Epoch 53: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - dir_acc: 0.7262 - loss: 0.1177 - val_dir_acc: 0.7080 - val_loss: 0.1368 - learning_rate: 0.0039
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0037846836971277367.
# Epoch 54/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7220 - loss: 0.1222
# Epoch 54: dir_acc improved from 0.71801 to 0.72684, saving model to transformer_train_model.keras
#
# Epoch 54: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - dir_acc: 0.7221 - loss: 0.1222 - val_dir_acc: 0.6638 - val_loss: 0.1228 - learning_rate: 0.0038
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.003687302312870132.
# Epoch 55/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.7147 - loss: 0.1202
# Epoch 55: dir_acc did not improve from 0.72684
#
# Epoch 55: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - dir_acc: 0.7148 - loss: 0.1202 - val_dir_acc: 0.7138 - val_loss: 0.1168 - learning_rate: 0.0037
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0035875399290983077.
# Epoch 56/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7294 - loss: 0.1192
# Epoch 56: dir_acc did not improve from 0.72684
#
# Epoch 56: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - dir_acc: 0.7293 - loss: 0.1192 - val_dir_acc: 0.6848 - val_loss: 0.1369 - learning_rate: 0.0036
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00348559745397654.
# Epoch 57/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7158 - loss: 0.1229
# Epoch 57: dir_acc did not improve from 0.72684
#
# Epoch 57: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - dir_acc: 0.7159 - loss: 0.1229 - val_dir_acc: 0.6929 - val_loss: 0.1180 - learning_rate: 0.0035
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0033816801860829505.
# Epoch 58/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7161 - loss: 0.1163
# Epoch 58: dir_acc did not improve from 0.72684
#
# Epoch 58: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - dir_acc: 0.7162 - loss: 0.1163 - val_dir_acc: 0.6652 - val_loss: 0.1139 - learning_rate: 0.0034
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0032759974009654944.
# Epoch 59/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7266 - loss: 0.1188
# Epoch 59: dir_acc did not improve from 0.72684
#
# Epoch 59: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - dir_acc: 0.7265 - loss: 0.1189 - val_dir_acc: 0.7004 - val_loss: 0.1182 - learning_rate: 0.0033
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0031687619296888545.
# Epoch 60/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7342 - loss: 0.1135
# Epoch 60: dir_acc improved from 0.72684 to 0.73149, saving model to transformer_train_model.keras
#
# Epoch 60: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.7342 - loss: 0.1136 - val_dir_acc: 0.6897 - val_loss: 0.1106 - learning_rate: 0.0032
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.003060189730221005.
# Epoch 61/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dir_acc: 0.7382 - loss: 0.1103
# Epoch 61: dir_acc improved from 0.73149 to 0.74036, saving model to transformer_train_model.keras
#
# Epoch 61: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - dir_acc: 0.7382 - loss: 0.1103 - val_dir_acc: 0.6987 - val_loss: 0.1109 - learning_rate: 0.0031
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.002950499452522599.
# Epoch 62/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7330 - loss: 0.1140
# Epoch 62: dir_acc did not improve from 0.74036
#
# Epoch 62: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - dir_acc: 0.7331 - loss: 0.1140 - val_dir_acc: 0.6741 - val_loss: 0.1209 - learning_rate: 0.0030
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0028399119982150506.
# Epoch 63/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7448 - loss: 0.1139
# Epoch 63: dir_acc improved from 0.74036 to 0.74218, saving model to transformer_train_model.keras
#
# Epoch 63: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - dir_acc: 0.7448 - loss: 0.1139 - val_dir_acc: 0.7018 - val_loss: 0.1134 - learning_rate: 0.0028
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.002728650075714067.
# Epoch 64/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7327 - loss: 0.1131
# Epoch 64: dir_acc did not improve from 0.74218
#
# Epoch 64: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - dir_acc: 0.7327 - loss: 0.1131 - val_dir_acc: 0.7317 - val_loss: 0.1110 - learning_rate: 0.0027
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0026169377517245352.
# Epoch 65/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7435 - loss: 0.1108
# Epoch 65: dir_acc did not improve from 0.74218
#
# Epoch 65: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - dir_acc: 0.7435 - loss: 0.1108 - val_dir_acc: 0.7272 - val_loss: 0.1152 - learning_rate: 0.0026
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0025050000000000003.
# Epoch 66/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7450 - loss: 0.1131
# Epoch 66: dir_acc did not improve from 0.74218
#
# Epoch 66: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - dir_acc: 0.7449 - loss: 0.1131 - val_dir_acc: 0.7076 - val_loss: 0.1097 - learning_rate: 0.0025
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0023930622482754658.
# Epoch 67/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7377 - loss: 0.1073
# Epoch 67: dir_acc improved from 0.74218 to 0.74236, saving model to transformer_train_model.keras
#
# Epoch 67: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.7377 - loss: 0.1073 - val_dir_acc: 0.7205 - val_loss: 0.1099 - learning_rate: 0.0024
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.002281349924285934.
# Epoch 68/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7547 - loss: 0.1060
# Epoch 68: dir_acc improved from 0.74236 to 0.75462, saving model to transformer_train_model.keras
#
# Epoch 68: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - dir_acc: 0.7547 - loss: 0.1060 - val_dir_acc: 0.7129 - val_loss: 0.1119 - learning_rate: 0.0023
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00217008800178495.
# Epoch 69/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7446 - loss: 0.1042
# Epoch 69: dir_acc did not improve from 0.75462
#
# Epoch 69: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - dir_acc: 0.7446 - loss: 0.1043 - val_dir_acc: 0.7040 - val_loss: 0.1144 - learning_rate: 0.0022
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.002059500547477402.
# Epoch 70/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7457 - loss: 0.1037
# Epoch 70: dir_acc did not improve from 0.75462
#
# Epoch 70: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - dir_acc: 0.7457 - loss: 0.1037 - val_dir_acc: 0.7196 - val_loss: 0.1046 - learning_rate: 0.0021
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.001949810269778996.
# Epoch 71/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7626 - loss: 0.0994
# Epoch 71: dir_acc improved from 0.75462 to 0.76032, saving model to transformer_train_model.keras
#
# Epoch 71: val_dir_acc did not improve from 0.73259
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - dir_acc: 0.7625 - loss: 0.0994 - val_dir_acc: 0.6996 - val_loss: 0.1120 - learning_rate: 0.0019
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0018412380703111465.
# Epoch 72/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7542 - loss: 0.1065
# Epoch 72: dir_acc did not improve from 0.76032
#
# Epoch 72: val_dir_acc improved from 0.73259 to 0.73616, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - dir_acc: 0.7542 - loss: 0.1065 - val_dir_acc: 0.7362 - val_loss: 0.1051 - learning_rate: 0.0018
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0017340025990345066.
# Epoch 73/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7588 - loss: 0.1027
# Epoch 73: dir_acc did not improve from 0.76032
#
# Epoch 73: val_dir_acc did not improve from 0.73616
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - dir_acc: 0.7588 - loss: 0.1027 - val_dir_acc: 0.7196 - val_loss: 0.1074 - learning_rate: 0.0017
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0016283198139170505.
# Epoch 74/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7715 - loss: 0.0998
# Epoch 74: dir_acc improved from 0.76032 to 0.76431, saving model to transformer_train_model.keras
#
# Epoch 74: val_dir_acc did not improve from 0.73616
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - dir_acc: 0.7714 - loss: 0.0998 - val_dir_acc: 0.7317 - val_loss: 0.1010 - learning_rate: 0.0016
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0015244025460234615.
# Epoch 75/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7653 - loss: 0.0987
# Epoch 75: dir_acc did not improve from 0.76431
#
# Epoch 75: val_dir_acc did not improve from 0.73616
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - dir_acc: 0.7653 - loss: 0.0987 - val_dir_acc: 0.7063 - val_loss: 0.1085 - learning_rate: 0.0015
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.001422460070901693.
# Epoch 76/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7610 - loss: 0.0953
# Epoch 76: dir_acc did not improve from 0.76431
#
# Epoch 76: val_dir_acc improved from 0.73616 to 0.73705, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - dir_acc: 0.7610 - loss: 0.0953 - val_dir_acc: 0.7371 - val_loss: 0.1065 - learning_rate: 0.0014
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0013226976871298685.
# Epoch 77/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7580 - loss: 0.0968
# Epoch 77: dir_acc improved from 0.76431 to 0.76530, saving model to transformer_train_model.keras
#
# Epoch 77: val_dir_acc did not improve from 0.73705
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - dir_acc: 0.7581 - loss: 0.0968 - val_dir_acc: 0.7107 - val_loss: 0.1031 - learning_rate: 0.0013
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0012253163028722645.
# Epoch 78/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7764 - loss: 0.0936
# Epoch 78: dir_acc improved from 0.76530 to 0.76938, saving model to transformer_train_model.keras
#
# Epoch 78: val_dir_acc improved from 0.73705 to 0.76250, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - dir_acc: 0.7764 - loss: 0.0936 - val_dir_acc: 0.7625 - val_loss: 0.1018 - learning_rate: 0.0012
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0011305120312770046.
# Epoch 79/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7753 - loss: 0.0958
# Epoch 79: dir_acc improved from 0.76938 to 0.77262, saving model to transformer_train_model.keras
#
# Epoch 79: val_dir_acc did not improve from 0.76250
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - dir_acc: 0.7753 - loss: 0.0958 - val_dir_acc: 0.7339 - val_loss: 0.1012 - learning_rate: 0.0011
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.00103847579553028.
# Epoch 80/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7704 - loss: 0.0928
# Epoch 80: dir_acc improved from 0.77262 to 0.77337, saving model to transformer_train_model.keras
#
# Epoch 80: val_dir_acc did not improve from 0.76250
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - dir_acc: 0.7704 - loss: 0.0928 - val_dir_acc: 0.7196 - val_loss: 0.1041 - learning_rate: 0.0010
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00094939294436246.
# Epoch 81/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7704 - loss: 0.0938
# Epoch 81: dir_acc improved from 0.77337 to 0.77662, saving model to transformer_train_model.keras
#
# Epoch 81: val_dir_acc did not improve from 0.76250
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - dir_acc: 0.7705 - loss: 0.0938 - val_dir_acc: 0.7330 - val_loss: 0.1002 - learning_rate: 9.4939e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0008634428787804172.
# Epoch 82/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7773 - loss: 0.0902
# Epoch 82: dir_acc improved from 0.77662 to 0.77742, saving model to transformer_train_model.keras
#
# Epoch 82: val_dir_acc did not improve from 0.76250
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - dir_acc: 0.7773 - loss: 0.0902 - val_dir_acc: 0.7616 - val_loss: 0.0968 - learning_rate: 8.6344e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0007807986907777728.
# Epoch 83/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7937 - loss: 0.0889
# Epoch 83: dir_acc improved from 0.77742 to 0.78441, saving model to transformer_train_model.keras
#
# Epoch 83: val_dir_acc improved from 0.76250 to 0.77500, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - dir_acc: 0.7936 - loss: 0.0889 - val_dir_acc: 0.7750 - val_loss: 0.0950 - learning_rate: 7.8080e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0007016268147506584.
# Epoch 84/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7758 - loss: 0.0903
# Epoch 84: dir_acc did not improve from 0.78441
#
# Epoch 84: val_dir_acc did not improve from 0.77500
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - dir_acc: 0.7758 - loss: 0.0903 - val_dir_acc: 0.7549 - val_loss: 0.0952 - learning_rate: 7.0163e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.000626086692320991.
# Epoch 85/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7926 - loss: 0.0922
# Epoch 85: dir_acc improved from 0.78441 to 0.78656, saving model to transformer_train_model.keras
#
# Epoch 85: val_dir_acc did not improve from 0.77500
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - dir_acc: 0.7925 - loss: 0.0922 - val_dir_acc: 0.7594 - val_loss: 0.0978 - learning_rate: 6.2609e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0005543304512422657.
# Epoch 86/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - dir_acc: 0.7878 - loss: 0.0888
# Epoch 86: dir_acc did not improve from 0.78656
#
# Epoch 86: val_dir_acc did not improve from 0.77500
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - dir_acc: 0.7878 - loss: 0.0888 - val_dir_acc: 0.7594 - val_loss: 0.0983 - learning_rate: 5.5433e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00048650259903450645.
# Epoch 87/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7797 - loss: 0.0892
# Epoch 87: dir_acc did not improve from 0.78656
#
# Epoch 87: val_dir_acc improved from 0.77500 to 0.78036, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - dir_acc: 0.7797 - loss: 0.0892 - val_dir_acc: 0.7804 - val_loss: 0.0952 - learning_rate: 4.8650e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00042273973196535.
# Epoch 88/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7843 - loss: 0.0897
# Epoch 88: dir_acc did not improve from 0.78656
#
# Epoch 88: val_dir_acc improved from 0.78036 to 0.78482, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - dir_acc: 0.7843 - loss: 0.0896 - val_dir_acc: 0.7848 - val_loss: 0.0960 - learning_rate: 4.2274e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00036317025996334415.
# Epoch 89/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7853 - loss: 0.0859
# Epoch 89: dir_acc improved from 0.78656 to 0.78881, saving model to transformer_train_model.keras
#
# Epoch 89: val_dir_acc did not improve from 0.78482
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - dir_acc: 0.7853 - loss: 0.0859 - val_dir_acc: 0.7562 - val_loss: 0.0922 - learning_rate: 3.6317e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00030791414801743875.
# Epoch 90/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7950 - loss: 0.0860
# Epoch 90: dir_acc did not improve from 0.78881
#
# Epoch 90: val_dir_acc did not improve from 0.78482
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - dir_acc: 0.7949 - loss: 0.0860 - val_dir_acc: 0.7661 - val_loss: 0.0927 - learning_rate: 3.0791e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00025708267458346456.
# Epoch 91/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7922 - loss: 0.0854
# Epoch 91: dir_acc improved from 0.78881 to 0.79440, saving model to transformer_train_model.keras
#
# Epoch 91: val_dir_acc improved from 0.78482 to 0.79821, saving model to transformer_val_model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 22s 113ms/step - dir_acc: 0.7922 - loss: 0.0854 - val_dir_acc: 0.7982 - val_loss: 0.0927 - learning_rate: 2.5708e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00021077820748413085.
# Epoch 92/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7812 - loss: 0.0865
# Epoch 92: dir_acc did not improve from 0.79440
#
# Epoch 92: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - dir_acc: 0.7813 - loss: 0.0865 - val_dir_acc: 0.7674 - val_loss: 0.0912 - learning_rate: 2.1078e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00016909399775385568.
# Epoch 93/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - dir_acc: 0.7922 - loss: 0.0858
# Epoch 93: dir_acc did not improve from 0.79440
#
# Epoch 93: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - dir_acc: 0.7922 - loss: 0.0858 - val_dir_acc: 0.7473 - val_loss: 0.0926 - learning_rate: 1.6909e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.00013211399184359196.
# Epoch 94/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.8045 - loss: 0.0838
# Epoch 94: dir_acc improved from 0.79440 to 0.79919, saving model to transformer_train_model.keras
#
# Epoch 94: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - dir_acc: 0.8045 - loss: 0.0838 - val_dir_acc: 0.7728 - val_loss: 0.0921 - learning_rate: 1.3211e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 9.991266256384617e-05.
# Epoch 95/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.7994 - loss: 0.0824
# Epoch 95: dir_acc did not improve from 0.79919
#
# Epoch 95: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - dir_acc: 0.7994 - loss: 0.0824 - val_dir_acc: 0.7772 - val_loss: 0.0916 - learning_rate: 9.9913e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 7.255485910635008e-05.
# Epoch 96/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7949 - loss: 0.0828
# Epoch 96: dir_acc did not improve from 0.79919
#
# Epoch 96: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - dir_acc: 0.7949 - loss: 0.0828 - val_dir_acc: 0.7772 - val_loss: 0.0915 - learning_rate: 7.2555e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 5.009567644641898e-05.
# Epoch 97/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7950 - loss: 0.0824
# Epoch 97: dir_acc did not improve from 0.79919
#
# Epoch 97: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - dir_acc: 0.7950 - loss: 0.0824 - val_dir_acc: 0.7772 - val_loss: 0.0916 - learning_rate: 5.0096e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.258034438900293e-05.
# Epoch 98/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dir_acc: 0.7912 - loss: 0.0845
# Epoch 98: dir_acc did not improve from 0.79919
#
# Epoch 98: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - dir_acc: 0.7912 - loss: 0.0845 - val_dir_acc: 0.7652 - val_loss: 0.0918 - learning_rate: 3.2580e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.0044136481878526e-05.
# Epoch 99/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.8032 - loss: 0.0810
# Epoch 99: dir_acc did not improve from 0.79919
#
# Epoch 99: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - dir_acc: 0.8031 - loss: 0.0810 - val_dir_acc: 0.7629 - val_loss: 0.0921 - learning_rate: 2.0044e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.25122989794201e-05.
# Epoch 100/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dir_acc: 0.8055 - loss: 0.0839
# Epoch 100: dir_acc improved from 0.79919 to 0.80370, saving model to transformer_train_model.keras
#
# Epoch 100: val_dir_acc did not improve from 0.79821
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - dir_acc: 0.8055 - loss: 0.0839 - val_dir_acc: 0.7772 - val_loss: 0.0916 - learning_rate: 1.2512e-05

# %%
model.load_weights("transformer_val_model.keras")  # Load the best model from the validation phase
accuracy = model.evaluate(test_sequences, test_labels)[1]  # Evaluate the model on the test data
print(accuracy)

from sklearn.metrics import r2_score

predictions = model.predict(test_sequences)  # Make predictions on the test dataset
r2 = r2_score(test_labels[:, 1], predictions[:, 0])  # Calculate R-squared value
print(f"R-squared: {r2}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - dir_acc: 0.7706 - loss: 0.0986
# 0.7759615182876587
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step
# R-squared: 0.9695555404185762

# %%
# prompt: plot a graph using matplotlib

import matplotlib.pyplot as plt

# Assuming you have 'test_labels' and 'predictions' available
# test_labels[:, 1] represents the true next values
# predictions[:, 0] represents the predicted next values

plt.figure(figsize=(12, 6))
plt.plot(test_labels[:, 1], label='True Next Values', color='blue')
plt.plot(predictions[:, 0], label='Predicted Next Values', color='red')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('True vs Predicted Stock Prices')
plt.legend()
plt.grid(True)
plt.show()
